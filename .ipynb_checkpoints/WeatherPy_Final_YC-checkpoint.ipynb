# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis -- Trend Observations
#
# Trend Observation 1:
# From the "City Latitude vs. Temperature (03/14/2019)" graph, the temperature climbs up quickly when approaching from both side of the polars to the equator;
# also I notice that North Sphere has more data in the chart, we may make an assumption that there are much less cities/countries existed passing the Antarctic Cirlcle (60ish degree) at the South Sphere.
#
# Trend Observation 2:
# From graph "City Latitude vs Humidity (03/14/2019)", although the correlation might seems low, we still can notice that the humidity among cities around equator retain relatively high-humidity, it might be caused by the heat around the equator area.
#
# Trend Observation 3:
# From graph "City Latitude vs Wind Speed (03/14/2019)", there is barely any correlation between latitude and wind speed; it indicates temperature is just one of the many factors that affecting the Wind Speed.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = pd.DataFrame({"Latitude":lats,"Longitude":lngs}) 

# Identify nearest city for each lat, lng combination
for index,row in lat_lngs.iterrows():
    city = citipy.nearest_city(row["Latitude"],row["Longitude"])
    lat_lngs.set_value(index,"Closest City name",city.city_name)
    lat_lngs.set_value(index,"Closest Country code",city.country_code.upper())
    
    
# Remove N/A values and duplicate cities
lat_lngs = lat_lngs.dropna()
lat_lngs = lat_lngs.drop_duplicates()

# Picking a sample of 500 cities for analysis
Cities = lat_lngs.sample(600)
Cities = Cities.reset_index()
Cities = Cities.iloc[:,[3,4]]
Cities.head()
# Out:
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   Closest City name Closest Country code
# 0            dikson                   RU
# 1        san rafael                   AR
# 2           te anau                   NZ
# 3     mar del plata                   AR
# 4             vaini                   TO

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
params = { "appid" :api_key,"units":"imperial" }

print("Beginning Data Retrieval")
print("-----------------------------------------\n")

for index,row in Cities.iterrows():
    params["q"] =f'{row["Closest City name"]},{row["Closest Country code"]}'
    print(f"Processing Record {index+1} of {len(Cities)} | for City,Country: {params['q']}")
    Results = requests.get(url,params)
   # print(Results.url)
    ResultsJson = Results.json()

# bringing values from json results to Cities dataset
    Cities.set_value(index,"Latitude",ResultsJson.get("coord",{}).get("lat"))
    Cities.set_value(index,"Longitude",ResultsJson.get("coord",{}).get("lon"))
    Cities.set_value(index,"Temperature",ResultsJson.get("coord",{}).get("lon"))
    Cities.set_value(index,"Max Temp",ResultsJson.get("main",{}).get("temp_max"))
    Cities.set_value(index,"Wind speed",ResultsJson.get("wind",{}).get("speed"))
    Cities.set_value(index,"Humidity",ResultsJson.get("main",{}).get("humidity"))
    Cities.set_value(index,"Cloudiness",ResultsJson.get("clouds",{}).get("all"))
    Cities.set_value(index,"Date",ResultsJson.get("dt"))

          
print("-----------------------------------------")
print("Data Retrieval Complete")
print("-----------------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------------------
#
# Processing Record 1 of 600 | for City,Country: dikson,RU
# Processing Record 2 of 600 | for City,Country: san rafael,AR
# Processing Record 3 of 600 | for City,Country: te anau,NZ
# Processing Record 4 of 600 | for City,Country: mar del plata,AR
# Processing Record 5 of 600 | for City,Country: vaini,TO
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\CY\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 6 of 600 | for City,Country: kulhudhuffushi,MV
# Processing Record 7 of 600 | for City,Country: mercedes,AR
# Processing Record 8 of 600 | for City,Country: ushuaia,AR
# Processing Record 9 of 600 | for City,Country: ambon,ID
# Processing Record 10 of 600 | for City,Country: saleaula,WS
# Processing Record 11 of 600 | for City,Country: rikitea,PF
# Processing Record 12 of 600 | for City,Country: hervey bay,AU
# Processing Record 13 of 600 | for City,Country: nanortalik,GL
# Processing Record 14 of 600 | for City,Country: arraial do cabo,BR
# Processing Record 15 of 600 | for City,Country: assiniboia,CA
# Processing Record 16 of 600 | for City,Country: pisco,PE
# Processing Record 17 of 600 | for City,Country: ushuaia,AR
# Processing Record 18 of 600 | for City,Country: bluff,NZ
# Processing Record 19 of 600 | for City,Country: bria,CF
# Processing Record 20 of 600 | for City,Country: qaanaaq,GL
# Processing Record 21 of 600 | for City,Country: cape town,ZA
# Processing Record 22 of 600 | for City,Country: rikitea,PF
# Processing Record 23 of 600 | for City,Country: bredasdorp,ZA
# Processing Record 24 of 600 | for City,Country: ushuaia,AR
# Processing Record 25 of 600 | for City,Country: shreveport,US
# Processing Record 26 of 600 | for City,Country: illoqqortoormiut,GL
# Processing Record 27 of 600 | for City,Country: thompson,CA
# Processing Record 28 of 600 | for City,Country: thessalon,CA
# Processing Record 29 of 600 | for City,Country: kavieng,PG
# Processing Record 30 of 600 | for City,Country: khatanga,RU
# Processing Record 31 of 600 | for City,Country: vanimo,PG
# Processing Record 32 of 600 | for City,Country: saskylakh,RU
# Processing Record 33 of 600 | for City,Country: ushuaia,AR
# Processing Record 34 of 600 | for City,Country: ushuaia,AR
# Processing Record 35 of 600 | for City,Country: tasiilaq,GL
# Processing Record 36 of 600 | for City,Country: sretensk,RU
# Processing Record 37 of 600 | for City,Country: tuatapere,NZ
# Processing Record 38 of 600 | for City,Country: attawapiskat,CA
# Processing Record 39 of 600 | for City,Country: basco,PH
# Processing Record 40 of 600 | for City,Country: hobart,AU
# Processing Record 41 of 600 | for City,Country: fortuna,US
# Processing Record 42 of 600 | for City,Country: taolanaro,MG
# Processing Record 43 of 600 | for City,Country: dikson,RU
# Processing Record 44 of 600 | for City,Country: albany,AU
# Processing Record 45 of 600 | for City,Country: coquimbo,CL
# Processing Record 46 of 600 | for City,Country: celestun,MX
# Processing Record 47 of 600 | for City,Country: georgetown,SH
# Processing Record 48 of 600 | for City,Country: fortuna,US
# Processing Record 49 of 600 | for City,Country: arraial do cabo,BR
# Processing Record 50 of 600 | for City,Country: wajima,JP
# Processing Record 51 of 600 | for City,Country: hithadhoo,MV
# Processing Record 52 of 600 | for City,Country: butaritari,KI
# Processing Record 53 of 600 | for City,Country: belushya guba,RU
# Processing Record 54 of 600 | for City,Country: orchard homes,US
# Processing Record 55 of 600 | for City,Country: bluff,NZ
# Processing Record 56 of 600 | for City,Country: arraial do cabo,BR
# Processing Record 57 of 600 | for City,Country: rikitea,PF
# Processing Record 58 of 600 | for City,Country: petropavlovsk-kamchatskiy,RU
# Processing Record 59 of 600 | for City,Country: east london,ZA
# Processing Record 60 of 600 | for City,Country: sentyabrskiy,RU
# Processing Record 61 of 600 | for City,Country: hofn,IS
# Processing Record 62 of 600 | for City,Country: hilo,US
# Processing Record 63 of 600 | for City,Country: hilo,US
# Processing Record 64 of 600 | for City,Country: rikitea,PF
# Processing Record 65 of 600 | for City,Country: tongren,CN
# Processing Record 66 of 600 | for City,Country: punta arenas,CL
# Processing Record 67 of 600 | for City,Country: mataura,PF
# Processing Record 68 of 600 | for City,Country: mataura,PF
# Processing Record 69 of 600 | for City,Country: faanui,PF
# Processing Record 70 of 600 | for City,Country: rikitea,PF
# Processing Record 71 of 600 | for City,Country: san cristobal,EC
# Processing Record 72 of 600 | for City,Country: cidreira,BR
# Processing Record 73 of 600 | for City,Country: melfi,TD
# Processing Record 74 of 600 | for City,Country: castro,CL
# Processing Record 75 of 600 | for City,Country: nikolskoye,RU
# Processing Record 76 of 600 | for City,Country: albany,AU
# Processing Record 77 of 600 | for City,Country: ushuaia,AR
# Processing Record 78 of 600 | for City,Country: bengkulu,ID
# Processing Record 79 of 600 | for City,Country: punta arenas,CL
# Processing Record 80 of 600 | for City,Country: zonguldak,TR
# Processing Record 81 of 600 | for City,Country: mar del plata,AR
# Processing Record 82 of 600 | for City,Country: kualakapuas,ID
# Processing Record 83 of 600 | for City,Country: fare,PF
# Processing Record 84 of 600 | for City,Country: port alfred,ZA
# Processing Record 85 of 600 | for City,Country: kerema,PG
# Processing Record 86 of 600 | for City,Country: hobart,AU
# Processing Record 87 of 600 | for City,Country: port elizabeth,ZA
# Processing Record 88 of 600 | for City,Country: yellowknife,CA
# Processing Record 89 of 600 | for City,Country: albany,AU
# Processing Record 90 of 600 | for City,Country: punta arenas,CL
# Processing Record 91 of 600 | for City,Country: bourail,NC
# Processing Record 92 of 600 | for City,Country: mataura,PF
# Processing Record 93 of 600 | for City,Country: jinchang,CN
# Processing Record 94 of 600 | for City,Country: rochegda,RU
# Processing Record 95 of 600 | for City,Country: sinnamary,GF
# Processing Record 96 of 600 | for City,Country: saint-philippe,RE
# Processing Record 97 of 600 | for City,Country: tarko-sale,RU
# Processing Record 98 of 600 | for City,Country: matara,LK
# Processing Record 99 of 600 | for City,Country: hualmay,PE
# Processing Record 100 of 600 | for City,Country: turayf,SA
# Processing Record 101 of 600 | for City,Country: suhbaatar,MN
# Processing Record 102 of 600 | for City,Country: nhulunbuy,AU
# Processing Record 103 of 600 | for City,Country: punta arenas,CL
# Processing Record 104 of 600 | for City,Country: albany,AU
# Processing Record 105 of 600 | for City,Country: albany,AU
# Processing Record 106 of 600 | for City,Country: berbera,SO
# Processing Record 107 of 600 | for City,Country: albany,AU
# Processing Record 108 of 600 | for City,Country: mataura,PF
# Processing Record 109 of 600 | for City,Country: ushuaia,AR
# Processing Record 110 of 600 | for City,Country: illoqqortoormiut,GL
# Processing Record 111 of 600 | for City,Country: concordia,AR
# Processing Record 112 of 600 | for City,Country: arklow,IE
# Processing Record 113 of 600 | for City,Country: bathsheba,BB
# Processing Record 114 of 600 | for City,Country: butaritari,KI
# Processing Record 115 of 600 | for City,Country: maniitsoq,GL
# Processing Record 116 of 600 | for City,Country: macheng,CN
# Processing Record 117 of 600 | for City,Country: umm lajj,SA
# Processing Record 118 of 600 | for City,Country: bredasdorp,ZA
# Processing Record 119 of 600 | for City,Country: jawhar,SO
# Processing Record 120 of 600 | for City,Country: ituni,GY
# Processing Record 121 of 600 | for City,Country: bluff,NZ
# Processing Record 122 of 600 | for City,Country: hermanus,ZA
# Processing Record 123 of 600 | for City,Country: hermanus,ZA
# Processing Record 124 of 600 | for City,Country: atuona,PF
# Processing Record 125 of 600 | for City,Country: marawi,SD
# Processing Record 126 of 600 | for City,Country: saint-pierre,PM
# Processing Record 127 of 600 | for City,Country: noumea,NC
# Processing Record 128 of 600 | for City,Country: rikitea,PF
# Processing Record 129 of 600 | for City,Country: tessalit,ML
# Processing Record 130 of 600 | for City,Country: hermanus,ZA
# Processing Record 131 of 600 | for City,Country: san quintin,MX
# Processing Record 132 of 600 | for City,Country: kamenka,RU
# Processing Record 133 of 600 | for City,Country: esperance,AU
# Processing Record 134 of 600 | for City,Country: broken hill,AU
# Processing Record 135 of 600 | for City,Country: egvekinot,RU
# Processing Record 136 of 600 | for City,Country: constitucion,MX
# Processing Record 137 of 600 | for City,Country: baykit,RU
# Processing Record 138 of 600 | for City,Country: butaritari,KI
# Processing Record 139 of 600 | for City,Country: keuruu,FI
# Processing Record 140 of 600 | for City,Country: klaksvik,FO
# Processing Record 141 of 600 | for City,Country: ushuaia,AR
# Processing Record 142 of 600 | for City,Country: rikitea,PF
# Processing Record 143 of 600 | for City,Country: mys shmidta,RU
# Processing Record 144 of 600 | for City,Country: ko samui,TH
# Processing Record 145 of 600 | for City,Country: tuktoyaktuk,CA
# Processing Record 146 of 600 | for City,Country: atuona,PF
# Processing Record 147 of 600 | for City,Country: bethel,US
# Processing Record 148 of 600 | for City,Country: bavly,RU
# Processing Record 149 of 600 | for City,Country: narsaq,GL
# Processing Record 150 of 600 | for City,Country: carnarvon,AU
# Processing Record 151 of 600 | for City,Country: nanortalik,GL
# Processing Record 152 of 600 | for City,Country: jamestown,SH
# Processing Record 153 of 600 | for City,Country: grootfontein,NA
# Processing Record 154 of 600 | for City,Country: gurskoye,RU
# Processing Record 155 of 600 | for City,Country: belushya guba,RU
# Processing Record 156 of 600 | for City,Country: ushuaia,AR
# Processing Record 157 of 600 | for City,Country: ilulissat,GL
# Processing Record 158 of 600 | for City,Country: grand gaube,MU
# Processing Record 159 of 600 | for City,Country: luderitz,NA
# Processing Record 160 of 600 | for City,Country: mys shmidta,RU
# Processing Record 161 of 600 | for City,Country: hami,CN
# Processing Record 162 of 600 | for City,Country: hobart,AU
# Processing Record 163 of 600 | for City,Country: koratla,IN
# Processing Record 164 of 600 | for City,Country: busselton,AU
# Processing Record 165 of 600 | for City,Country: kavaratti,IN
# Processing Record 166 of 600 | for City,Country: alihe,CN
# Processing Record 167 of 600 | for City,Country: torbay,CA
# Processing Record 168 of 600 | for City,Country: tabiauea,KI
# Processing Record 169 of 600 | for City,Country: tiksi,RU
# Processing Record 170 of 600 | for City,Country: tuktoyaktuk,CA
# Processing Record 171 of 600 | for City,Country: atuona,PF
# Processing Record 172 of 600 | for City,Country: medianeira,BR
# Processing Record 173 of 600 | for City,Country: hovd,MN
# Processing Record 174 of 600 | for City,Country: bredasdorp,ZA
# Processing Record 175 of 600 | for City,Country: puerto ayora,EC
# Processing Record 176 of 600 | for City,Country: cape town,ZA
# Processing Record 177 of 600 | for City,Country: bluff,NZ
# Processing Record 178 of 600 | for City,Country: attawapiskat,CA
# Processing Record 179 of 600 | for City,Country: bambous virieux,MU
# Processing Record 180 of 600 | for City,Country: tigzirt,DZ
# Processing Record 181 of 600 | for City,Country: husavik,IS
# Processing Record 182 of 600 | for City,Country: ushuaia,AR
# Processing Record 183 of 600 | for City,Country: upernavik,GL
# Processing Record 184 of 600 | for City,Country: atuona,PF
# Processing Record 185 of 600 | for City,Country: bethel,US
# Processing Record 186 of 600 | for City,Country: harper,LR
# Processing Record 187 of 600 | for City,Country: biak,ID
# Processing Record 188 of 600 | for City,Country: san joaquin,BO
# Processing Record 189 of 600 | for City,Country: lolua,TV
# Processing Record 190 of 600 | for City,Country: hermanus,ZA
# Processing Record 191 of 600 | for City,Country: cervo,ES
# Processing Record 192 of 600 | for City,Country: den helder,NL
# Processing Record 193 of 600 | for City,Country: teyateyaneng,LS
# Processing Record 194 of 600 | for City,Country: chuy,UY
# Processing Record 195 of 600 | for City,Country: qaanaaq,GL
# Processing Record 196 of 600 | for City,Country: tuktoyaktuk,CA
# Processing Record 197 of 600 | for City,Country: pisco,PE
# Processing Record 198 of 600 | for City,Country: vao,NC
# Processing Record 199 of 600 | for City,Country: rikitea,PF
# Processing Record 200 of 600 | for City,Country: amderma,RU
# Processing Record 201 of 600 | for City,Country: amderma,RU
# Processing Record 202 of 600 | for City,Country: cockburn town,BS
# Processing Record 203 of 600 | for City,Country: pevek,RU
# Processing Record 204 of 600 | for City,Country: barrow,US
# Processing Record 205 of 600 | for City,Country: baoning,CN
# Processing Record 206 of 600 | for City,Country: leningradskiy,RU
# Processing Record 207 of 600 | for City,Country: sibu,MY
# Processing Record 208 of 600 | for City,Country: mar del plata,AR
# Processing Record 209 of 600 | for City,Country: leningradskiy,RU
# Processing Record 210 of 600 | for City,Country: pevek,RU
# Processing Record 211 of 600 | for City,Country: suwannaphum,TH
# Processing Record 212 of 600 | for City,Country: bluff,NZ
# Processing Record 213 of 600 | for City,Country: albany,AU
# Processing Record 214 of 600 | for City,Country: ossora,RU
# Processing Record 215 of 600 | for City,Country: bethel,US
# Processing Record 216 of 600 | for City,Country: arraial do cabo,BR
# Processing Record 217 of 600 | for City,Country: illoqqortoormiut,GL
# Processing Record 218 of 600 | for City,Country: ribeira grande,PT
# Processing Record 219 of 600 | for City,Country: kaitangata,NZ
# Processing Record 220 of 600 | for City,Country: bara,SD
# Processing Record 221 of 600 | for City,Country: busselton,AU
# Processing Record 222 of 600 | for City,Country: alofi,NU
# Processing Record 223 of 600 | for City,Country: east london,ZA
# Processing Record 224 of 600 | for City,Country: silopi,TR
# Processing Record 225 of 600 | for City,Country: hobart,AU
# Processing Record 226 of 600 | for City,Country: deputatskiy,RU
# Processing Record 227 of 600 | for City,Country: chokurdakh,RU
# Processing Record 228 of 600 | for City,Country: butaritari,KI
# Processing Record 229 of 600 | for City,Country: hobart,AU
# Processing Record 230 of 600 | for City,Country: khatanga,RU
# Processing Record 231 of 600 | for City,Country: cidreira,BR
# Processing Record 232 of 600 | for City,Country: atuona,PF
# Processing Record 233 of 600 | for City,Country: rikitea,PF
# Processing Record 234 of 600 | for City,Country: tumannyy,RU
# Processing Record 235 of 600 | for City,Country: dikson,RU
# Processing Record 236 of 600 | for City,Country: torbay,CA
# Processing Record 237 of 600 | for City,Country: khatanga,RU
# Processing Record 238 of 600 | for City,Country: amderma,RU
# Processing Record 239 of 600 | for City,Country: albany,AU
# Processing Record 240 of 600 | for City,Country: labuhan,ID
# Processing Record 241 of 600 | for City,Country: hobart,AU
# Processing Record 242 of 600 | for City,Country: bredasdorp,ZA
# Processing Record 243 of 600 | for City,Country: mahebourg,MU
# Processing Record 244 of 600 | for City,Country: rikitea,PF
# Processing Record 245 of 600 | for City,Country: petrovskaya,RU
# Processing Record 246 of 600 | for City,Country: hilo,US
# Processing Record 247 of 600 | for City,Country: hofn,IS
# Processing Record 248 of 600 | for City,Country: kavaratti,IN
# Processing Record 249 of 600 | for City,Country: rikitea,PF
# Processing Record 250 of 600 | for City,Country: abha,SA
# Processing Record 251 of 600 | for City,Country: totness,SR
# Processing Record 252 of 600 | for City,Country: klaksvik,FO
# Processing Record 253 of 600 | for City,Country: avarua,CK
# Processing Record 254 of 600 | for City,Country: mataura,PF
# Processing Record 255 of 600 | for City,Country: new norfolk,AU
# Processing Record 256 of 600 | for City,Country: busselton,AU
# Processing Record 257 of 600 | for City,Country: udachnyy,RU
# Processing Record 258 of 600 | for City,Country: tecoanapa,MX
# Processing Record 259 of 600 | for City,Country: salina cruz,MX
# Processing Record 260 of 600 | for City,Country: norman wells,CA
# Processing Record 261 of 600 | for City,Country: kyra,RU
# Processing Record 262 of 600 | for City,Country: faya,TD
# Processing Record 263 of 600 | for City,Country: new norfolk,AU
# Processing Record 264 of 600 | for City,Country: albany,AU
# Processing Record 265 of 600 | for City,Country: missoula,US
# Processing Record 266 of 600 | for City,Country: hithadhoo,MV
# Processing Record 267 of 600 | for City,Country: peniche,PT
# Processing Record 268 of 600 | for City,Country: bengkulu,ID
# Processing Record 269 of 600 | for City,Country: clyde river,CA
# Processing Record 270 of 600 | for City,Country: poltavka,RU
# Processing Record 271 of 600 | for City,Country: merauke,ID
# Processing Record 272 of 600 | for City,Country: avarua,CK
# Processing Record 273 of 600 | for City,Country: rikitea,PF
# Processing Record 274 of 600 | for City,Country: sur,OM
# Processing Record 275 of 600 | for City,Country: geraldton,AU
# Processing Record 276 of 600 | for City,Country: marcona,PE
# Processing Record 277 of 600 | for City,Country: jamestown,SH
# Processing Record 278 of 600 | for City,Country: hay river,CA
# Processing Record 279 of 600 | for City,Country: yellowknife,CA
# Processing Record 280 of 600 | for City,Country: chuy,UY
# Processing Record 281 of 600 | for City,Country: somerset west,ZA
# Processing Record 282 of 600 | for City,Country: new norfolk,AU
# Processing Record 283 of 600 | for City,Country: rikitea,PF
# Processing Record 284 of 600 | for City,Country: sug-aksy,RU
# Processing Record 285 of 600 | for City,Country: muros,ES
# Processing Record 286 of 600 | for City,Country: half moon bay,US
# Processing Record 287 of 600 | for City,Country: busselton,AU
# Processing Record 288 of 600 | for City,Country: punta arenas,CL
# Processing Record 289 of 600 | for City,Country: majene,ID
# Processing Record 290 of 600 | for City,Country: cootamundra,AU
# Processing Record 291 of 600 | for City,Country: illoqqortoormiut,GL
# Processing Record 292 of 600 | for City,Country: ushuaia,AR
# Processing Record 293 of 600 | for City,Country: qabaqcol,AZ
# Processing Record 294 of 600 | for City,Country: kapaa,US
# Processing Record 295 of 600 | for City,Country: taolanaro,MG
# Processing Record 296 of 600 | for City,Country: istiaia,GR
# Processing Record 297 of 600 | for City,Country: saint anthony,CA
# Processing Record 298 of 600 | for City,Country: shadrinsk,RU
# Processing Record 299 of 600 | for City,Country: bowen,AU
# Processing Record 300 of 600 | for City,Country: victoria,SC
# Processing Record 301 of 600 | for City,Country: ribeira grande,PT
# Processing Record 302 of 600 | for City,Country: leningradskiy,RU
# Processing Record 303 of 600 | for City,Country: ugoofaaru,MV
# Processing Record 304 of 600 | for City,Country: victoria,SC
# Processing Record 305 of 600 | for City,Country: vaini,TO
# Processing Record 306 of 600 | for City,Country: dingle,IE
# Processing Record 307 of 600 | for City,Country: tanout,NE
# Processing Record 308 of 600 | for City,Country: bredasdorp,ZA
# Processing Record 309 of 600 | for City,Country: kapaa,US
# Processing Record 310 of 600 | for City,Country: berlevag,NO
# Processing Record 311 of 600 | for City,Country: castro,CL
# Processing Record 312 of 600 | for City,Country: georgetown,SH
# Processing Record 313 of 600 | for City,Country: vanimo,PG
# Processing Record 314 of 600 | for City,Country: roswell,US
# Processing Record 315 of 600 | for City,Country: klaksvik,FO
# Processing Record 316 of 600 | for City,Country: jamestown,SH
# Processing Record 317 of 600 | for City,Country: mataura,PF
# Processing Record 318 of 600 | for City,Country: rikitea,PF
# Processing Record 319 of 600 | for City,Country: saint-joseph,RE
# Processing Record 320 of 600 | for City,Country: kapaa,US
# Processing Record 321 of 600 | for City,Country: atuona,PF
# Processing Record 322 of 600 | for City,Country: kapaa,US
# Processing Record 323 of 600 | for City,Country: kodiak,US
# Processing Record 324 of 600 | for City,Country: phanom sarakham,TH
# Processing Record 325 of 600 | for City,Country: khatanga,RU
# Processing Record 326 of 600 | for City,Country: saldanha,ZA
# Processing Record 327 of 600 | for City,Country: witu,KE
# Processing Record 328 of 600 | for City,Country: mataura,PF
# Processing Record 329 of 600 | for City,Country: qaanaaq,GL
# Processing Record 330 of 600 | for City,Country: bluff,NZ
# Processing Record 331 of 600 | for City,Country: kapaa,US
# Processing Record 332 of 600 | for City,Country: rikitea,PF
# Processing Record 333 of 600 | for City,Country: cherskiy,RU
# Processing Record 334 of 600 | for City,Country: jiddah,SA
# Processing Record 335 of 600 | for City,Country: illoqqortoormiut,GL
# Processing Record 336 of 600 | for City,Country: taolanaro,MG
# Processing Record 337 of 600 | for City,Country: port lincoln,AU
# Processing Record 338 of 600 | for City,Country: ahuimanu,US
# Processing Record 339 of 600 | for City,Country: bluff,NZ
# Processing Record 340 of 600 | for City,Country: georgetown,SH
# Processing Record 341 of 600 | for City,Country: caravelas,BR
# Processing Record 342 of 600 | for City,Country: bilibino,RU
# Processing Record 343 of 600 | for City,Country: ushuaia,AR
# Processing Record 344 of 600 | for City,Country: illoqqortoormiut,GL
# Processing Record 345 of 600 | for City,Country: baruun-urt,MN
# Processing Record 346 of 600 | for City,Country: fairbanks,US
# Processing Record 347 of 600 | for City,Country: hilo,US
# Processing Record 348 of 600 | for City,Country: hilo,US
# Processing Record 349 of 600 | for City,Country: hermanus,ZA
# Processing Record 350 of 600 | for City,Country: hermanus,ZA
# Processing Record 351 of 600 | for City,Country: lebu,CL
# Processing Record 352 of 600 | for City,Country: sentyabrskiy,RU
# Processing Record 353 of 600 | for City,Country: chalmette,US
# Processing Record 354 of 600 | for City,Country: vaini,TO
# Processing Record 355 of 600 | for City,Country: kavaratti,IN
# Processing Record 356 of 600 | for City,Country: buala,SB
# Processing Record 357 of 600 | for City,Country: tuktoyaktuk,CA
# Processing Record 358 of 600 | for City,Country: srednekolymsk,RU
# Processing Record 359 of 600 | for City,Country: sumbe,AO
# Processing Record 360 of 600 | for City,Country: pirenopolis,BR
# Processing Record 361 of 600 | for City,Country: pedasi,PA
# Processing Record 362 of 600 | for City,Country: leningradskiy,RU
# Processing Record 363 of 600 | for City,Country: broken hill,AU
# Processing Record 364 of 600 | for City,Country: taolanaro,MG
# Processing Record 365 of 600 | for City,Country: baykit,RU
# Processing Record 366 of 600 | for City,Country: datong,CN
# Processing Record 367 of 600 | for City,Country: jamestown,SH
# Processing Record 368 of 600 | for City,Country: gisborne,NZ
# Processing Record 369 of 600 | for City,Country: jamestown,SH
# Processing Record 370 of 600 | for City,Country: mataura,PF
# Processing Record 371 of 600 | for City,Country: grand river south east,MU
# Processing Record 372 of 600 | for City,Country: ushuaia,AR
# Processing Record 373 of 600 | for City,Country: avarua,CK
# Processing Record 374 of 600 | for City,Country: jacareacanga,BR
# Processing Record 375 of 600 | for City,Country: port moresby,PG
# Processing Record 376 of 600 | for City,Country: ushuaia,AR
# Processing Record 377 of 600 | for City,Country: ushuaia,AR
# Processing Record 378 of 600 | for City,Country: sa kaeo,TH
# Processing Record 379 of 600 | for City,Country: rikitea,PF
# Processing Record 380 of 600 | for City,Country: puerto ayora,EC
# Processing Record 381 of 600 | for City,Country: butaritari,KI
# Processing Record 382 of 600 | for City,Country: rikitea,PF
# Processing Record 383 of 600 | for City,Country: codrington,AG
# Processing Record 384 of 600 | for City,Country: sao filipe,CV
# Processing Record 385 of 600 | for City,Country: ziro,IN
# Processing Record 386 of 600 | for City,Country: dikson,RU
# Processing Record 387 of 600 | for City,Country: puerto leguizamo,CO
# Processing Record 388 of 600 | for City,Country: mar del plata,AR
# Processing Record 389 of 600 | for City,Country: port moresby,PG
# Processing Record 390 of 600 | for City,Country: ushuaia,AR
# Processing Record 391 of 600 | for City,Country: ushuaia,AR
# Processing Record 392 of 600 | for City,Country: punta arenas,CL
# Processing Record 393 of 600 | for City,Country: rikitea,PF
# Processing Record 394 of 600 | for City,Country: nizhneyansk,RU
# Processing Record 395 of 600 | for City,Country: tuktoyaktuk,CA
# Processing Record 396 of 600 | for City,Country: saskylakh,RU
# Processing Record 397 of 600 | for City,Country: yellowknife,CA
# Processing Record 398 of 600 | for City,Country: bargal,SO
# Processing Record 399 of 600 | for City,Country: taolanaro,MG
# Processing Record 400 of 600 | for City,Country: sitka,US
# Processing Record 401 of 600 | for City,Country: sorvag,FO
# Processing Record 402 of 600 | for City,Country: kaitangata,NZ
# Processing Record 403 of 600 | for City,Country: daru,PG
# Processing Record 404 of 600 | for City,Country: albany,AU
# Processing Record 405 of 600 | for City,Country: aykhal,RU
# Processing Record 406 of 600 | for City,Country: grand river south east,MU
# Processing Record 407 of 600 | for City,Country: hobart,AU
# Processing Record 408 of 600 | for City,Country: codrington,AG
# Processing Record 409 of 600 | for City,Country: severo-kurilsk,RU
# Processing Record 410 of 600 | for City,Country: faya,TD
# Processing Record 411 of 600 | for City,Country: vila,VU
# Processing Record 412 of 600 | for City,Country: carnarvon,ZA
# Processing Record 413 of 600 | for City,Country: mbabane,SZ
# Processing Record 414 of 600 | for City,Country: punta arenas,CL
# Processing Record 415 of 600 | for City,Country: tura,RU
# Processing Record 416 of 600 | for City,Country: guarapari,BR
# Processing Record 417 of 600 | for City,Country: yellowknife,CA
# Processing Record 418 of 600 | for City,Country: atambua,ID
# Processing Record 419 of 600 | for City,Country: alice springs,AU
# Processing Record 420 of 600 | for City,Country: arraial do cabo,BR
# Processing Record 421 of 600 | for City,Country: port alfred,ZA
# Processing Record 422 of 600 | for City,Country: chuy,UY
# Processing Record 423 of 600 | for City,Country: rikitea,PF
# Processing Record 424 of 600 | for City,Country: acarau,BR
# Processing Record 425 of 600 | for City,Country: palembang,ID
# Processing Record 426 of 600 | for City,Country: geraldton,AU
# Processing Record 427 of 600 | for City,Country: victoria,SC
# Processing Record 428 of 600 | for City,Country: airai,PW
# Processing Record 429 of 600 | for City,Country: mar del plata,AR
# Processing Record 430 of 600 | for City,Country: souillac,MU
# Processing Record 431 of 600 | for City,Country: busselton,AU
# Processing Record 432 of 600 | for City,Country: ushuaia,AR
# Processing Record 433 of 600 | for City,Country: kahului,US
# Processing Record 434 of 600 | for City,Country: butaritari,KI
# Processing Record 435 of 600 | for City,Country: maine-soroa,NE
# Processing Record 436 of 600 | for City,Country: castro,CL
# Processing Record 437 of 600 | for City,Country: new norfolk,AU
# Processing Record 438 of 600 | for City,Country: busselton,AU
# Processing Record 439 of 600 | for City,Country: mackay,AU
# Processing Record 440 of 600 | for City,Country: gladstone,AU
# Processing Record 441 of 600 | for City,Country: kanker,IN
# Processing Record 442 of 600 | for City,Country: yumen,CN
# Processing Record 443 of 600 | for City,Country: vila,VU
# Processing Record 444 of 600 | for City,Country: havelock,US
# Processing Record 445 of 600 | for City,Country: makakilo city,US
# Processing Record 446 of 600 | for City,Country: taolanaro,MG
# Processing Record 447 of 600 | for City,Country: albany,AU
# Processing Record 448 of 600 | for City,Country: kapaa,US
# Processing Record 449 of 600 | for City,Country: halalo,WF
# Processing Record 450 of 600 | for City,Country: chuy,UY
# Processing Record 451 of 600 | for City,Country: hithadhoo,MV
# Processing Record 452 of 600 | for City,Country: longyan,CN
# Processing Record 453 of 600 | for City,Country: ushuaia,AR
# Processing Record 454 of 600 | for City,Country: saint george,BM
# Processing Record 455 of 600 | for City,Country: cape town,ZA
# Processing Record 456 of 600 | for City,Country: sechura,PE
# Processing Record 457 of 600 | for City,Country: taolanaro,MG
# Processing Record 458 of 600 | for City,Country: port elizabeth,ZA
# Processing Record 459 of 600 | for City,Country: punta alta,AR
# Processing Record 460 of 600 | for City,Country: port alfred,ZA
# Processing Record 461 of 600 | for City,Country: primorsk,RU
# Processing Record 462 of 600 | for City,Country: saint-philippe,RE
# Processing Record 463 of 600 | for City,Country: cidreira,BR
# Processing Record 464 of 600 | for City,Country: taolanaro,MG
# Processing Record 465 of 600 | for City,Country: fairbanks,US
# Processing Record 466 of 600 | for City,Country: ushuaia,AR
# Processing Record 467 of 600 | for City,Country: ushuaia,AR
# Processing Record 468 of 600 | for City,Country: tasiilaq,GL
# Processing Record 469 of 600 | for City,Country: saldanha,ZA
# Processing Record 470 of 600 | for City,Country: kinango,KE
# Processing Record 471 of 600 | for City,Country: rikitea,PF
# Processing Record 472 of 600 | for City,Country: namibe,AO
# Processing Record 473 of 600 | for City,Country: buzmeyin,TM
# Processing Record 474 of 600 | for City,Country: victoria,SC
# Processing Record 475 of 600 | for City,Country: sorland,NO
# Processing Record 476 of 600 | for City,Country: albany,AU
# Processing Record 477 of 600 | for City,Country: khatanga,RU
# Processing Record 478 of 600 | for City,Country: atuona,PF
# Processing Record 479 of 600 | for City,Country: lorengau,PG
# Processing Record 480 of 600 | for City,Country: vaini,TO
# Processing Record 481 of 600 | for City,Country: roald,NO
# Processing Record 482 of 600 | for City,Country: klaksvik,FO
# Processing Record 483 of 600 | for City,Country: rikitea,PF
# Processing Record 484 of 600 | for City,Country: port-cartier,CA
# Processing Record 485 of 600 | for City,Country: los llanos de aridane,ES
# Processing Record 486 of 600 | for City,Country: rikitea,PF
# Processing Record 487 of 600 | for City,Country: hermanus,ZA
# Processing Record 488 of 600 | for City,Country: kudahuvadhoo,MV
# Processing Record 489 of 600 | for City,Country: namibe,AO
# Processing Record 490 of 600 | for City,Country: komsomolskiy,RU
# Processing Record 491 of 600 | for City,Country: yellowknife,CA
# Processing Record 492 of 600 | for City,Country: barentsburg,SJ
# Processing Record 493 of 600 | for City,Country: mahebourg,MU
# Processing Record 494 of 600 | for City,Country: ponca city,US
# Processing Record 495 of 600 | for City,Country: chokurdakh,RU
# Processing Record 496 of 600 | for City,Country: ponta do sol,PT
# Processing Record 497 of 600 | for City,Country: preobrazheniye,RU
# Processing Record 498 of 600 | for City,Country: tuktoyaktuk,CA
# Processing Record 499 of 600 | for City,Country: chokurdakh,RU
# Processing Record 500 of 600 | for City,Country: canapi,BR
# Processing Record 501 of 600 | for City,Country: ushuaia,AR
# Processing Record 502 of 600 | for City,Country: taolanaro,MG
# Processing Record 503 of 600 | for City,Country: namatanai,PG
# Processing Record 504 of 600 | for City,Country: vaini,TO
# Processing Record 505 of 600 | for City,Country: cayenne,GF
# Processing Record 506 of 600 | for City,Country: bluff,NZ
# Processing Record 507 of 600 | for City,Country: ushuaia,AR
# Processing Record 508 of 600 | for City,Country: evensk,RU
# Processing Record 509 of 600 | for City,Country: arlit,NE
# Processing Record 510 of 600 | for City,Country: opuwo,NA
# Processing Record 511 of 600 | for City,Country: krasnoselkup,RU
# Processing Record 512 of 600 | for City,Country: mataura,PF
# Processing Record 513 of 600 | for City,Country: vaini,TO
# Processing Record 514 of 600 | for City,Country: puerto ayora,EC
# Processing Record 515 of 600 | for City,Country: ushuaia,AR
# Processing Record 516 of 600 | for City,Country: tiksi,RU
# Processing Record 517 of 600 | for City,Country: arraial do cabo,BR
# Processing Record 518 of 600 | for City,Country: rikitea,PF
# Processing Record 519 of 600 | for City,Country: immokalee,US
# Processing Record 520 of 600 | for City,Country: rikitea,PF
# Processing Record 521 of 600 | for City,Country: avarua,CK
# Processing Record 522 of 600 | for City,Country: amderma,RU
# Processing Record 523 of 600 | for City,Country: hithadhoo,MV
# Processing Record 524 of 600 | for City,Country: bredasdorp,ZA
# Processing Record 525 of 600 | for City,Country: mar del plata,AR
# Processing Record 526 of 600 | for City,Country: busselton,AU
# Processing Record 527 of 600 | for City,Country: cape town,ZA
# Processing Record 528 of 600 | for City,Country: balkanabat,TM
# Processing Record 529 of 600 | for City,Country: tumannyy,RU
# Processing Record 530 of 600 | for City,Country: hobart,AU
# Processing Record 531 of 600 | for City,Country: bako,ET
# Processing Record 532 of 600 | for City,Country: atuona,PF
# Processing Record 533 of 600 | for City,Country: samusu,WS
# Processing Record 534 of 600 | for City,Country: jamestown,SH
# Processing Record 535 of 600 | for City,Country: port lincoln,AU
# Processing Record 536 of 600 | for City,Country: chebenki,RU
# Processing Record 537 of 600 | for City,Country: thompson,CA
# Processing Record 538 of 600 | for City,Country: cabo san lucas,MX
# Processing Record 539 of 600 | for City,Country: severo-kurilsk,RU
# Processing Record 540 of 600 | for City,Country: taolanaro,MG
# Processing Record 541 of 600 | for City,Country: saint-georges,GF
# Processing Record 542 of 600 | for City,Country: kavieng,PG
# Processing Record 543 of 600 | for City,Country: barentsburg,SJ
# Processing Record 544 of 600 | for City,Country: rikitea,PF
# Processing Record 545 of 600 | for City,Country: hofn,IS
# Processing Record 546 of 600 | for City,Country: carnarvon,ZA
# Processing Record 547 of 600 | for City,Country: banikoara,BJ
# Processing Record 548 of 600 | for City,Country: rush,IE
# Processing Record 549 of 600 | for City,Country: kapaa,US
# Processing Record 550 of 600 | for City,Country: diu,IN
# Processing Record 551 of 600 | for City,Country: hobart,AU
# Processing Record 552 of 600 | for City,Country: puerto escondido,MX
# Processing Record 553 of 600 | for City,Country: mar del plata,AR
# Processing Record 554 of 600 | for City,Country: poli,TZ
# Processing Record 555 of 600 | for City,Country: alofi,NU
# Processing Record 556 of 600 | for City,Country: faya,TD
# Processing Record 557 of 600 | for City,Country: itoman,JP
# Processing Record 558 of 600 | for City,Country: jinji,CN
# Processing Record 559 of 600 | for City,Country: baykit,RU
# Processing Record 560 of 600 | for City,Country: edd,ER
# Processing Record 561 of 600 | for City,Country: pisco,PE
# Processing Record 562 of 600 | for City,Country: carnarvon,AU
# Processing Record 563 of 600 | for City,Country: ushuaia,AR
# Processing Record 564 of 600 | for City,Country: vaini,TO
# Processing Record 565 of 600 | for City,Country: rikitea,PF
# Processing Record 566 of 600 | for City,Country: telsiai,LT
# Processing Record 567 of 600 | for City,Country: saint-pierre,PM
# Processing Record 568 of 600 | for City,Country: ushuaia,AR
# Processing Record 569 of 600 | for City,Country: rikitea,PF
# Processing Record 570 of 600 | for City,Country: nelson bay,AU
# Processing Record 571 of 600 | for City,Country: busselton,AU
# Processing Record 572 of 600 | for City,Country: taolanaro,MG
# Processing Record 573 of 600 | for City,Country: ushuaia,AR
# Processing Record 574 of 600 | for City,Country: isangel,VU
# Processing Record 575 of 600 | for City,Country: deh rawud,AF
# Processing Record 576 of 600 | for City,Country: severo-kurilsk,RU
# Processing Record 577 of 600 | for City,Country: rikitea,PF
# Processing Record 578 of 600 | for City,Country: castanos,MX
# Processing Record 579 of 600 | for City,Country: minab,IR
# Processing Record 580 of 600 | for City,Country: honiara,SB
# Processing Record 581 of 600 | for City,Country: hihifo,TO
# Processing Record 582 of 600 | for City,Country: beyneu,KZ
# Processing Record 583 of 600 | for City,Country: jaumave,MX
# Processing Record 584 of 600 | for City,Country: lolua,TV
# Processing Record 585 of 600 | for City,Country: kodiak,US
# Processing Record 586 of 600 | for City,Country: ushuaia,AR
# Processing Record 587 of 600 | for City,Country: port elizabeth,ZA
# Processing Record 588 of 600 | for City,Country: matadi,CD
# Processing Record 589 of 600 | for City,Country: victor harbor,AU
# Processing Record 590 of 600 | for City,Country: karaul,RU
# Processing Record 591 of 600 | for City,Country: san miguel,PE
# Processing Record 592 of 600 | for City,Country: rundu,NA
# Processing Record 593 of 600 | for City,Country: bluff,NZ
# Processing Record 594 of 600 | for City,Country: severo-kurilsk,RU
# Processing Record 595 of 600 | for City,Country: hermitage,US
# Processing Record 596 of 600 | for City,Country: poronaysk,RU
# Processing Record 597 of 600 | for City,Country: hasaki,JP
# Processing Record 598 of 600 | for City,Country: sao joao da barra,BR
# Processing Record 599 of 600 | for City,Country: vaini,TO
# Processing Record 600 of 600 | for City,Country: trudovoye,RU
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Drop cities that are non-exist
Cities = Cities.dropna()
Cities.head()
# Creat a city weather info dataframe; rename the columns
City_Weather_Data = pd.DataFrame({"City":Cities["Closest City name"],
                         "Cloudiness":Cities["Cloudiness"],
                         "Country":Cities["Closest Country code"],
                         "Date":Cities["Date"],
                         "Humidity":Cities["Humidity"],
                         "Lat":Cities["Latitude"],
                         "Lng":Cities["Longitude"],
                         "Max_Temp":Cities["Max Temp"],
                         "Wind_Speed":Cities["Wind speed"],})

# Save CSV of all data retrieved 
City_Weather_Data.to_csv("Sample_City_Weather_data.csv")

# %%
# Display the City Dataa Frame
City_Weather_Data["Date"] = City_Weather_Data["Date"].astype('int')
City_Weather_Data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         dikson        80.0      RU  1552596118     100.0  73.51   80.55
# 1     san rafael         0.0      AR  1552596118      21.0 -34.61  -68.33
# 2        te anau         8.0      NZ  1552596118      92.0 -45.41  167.72
# 3  mar del plata        92.0      AR  1552596118      94.0 -46.43  -67.52
# 4          vaini        75.0      TO  1552593600     100.0 -21.20 -175.20
#
#    Max_Temp  Wind_Speed
# 0      4.97       18.19
# 1     74.90       10.13
# 2     45.34        3.53
# 3     55.87       13.38
# 4     77.00        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plot the data in scatter Chart
import seaborn
seaborn.set()

plt.scatter(City_Weather_Data.Lat, City_Weather_Data.Max_Temp)
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title("City Latitude vs. Temperature (03/14/2019)")

# Save png images for the scatter plot.
plt.savefig("CityLat_vs_MaxTemp_03.14.19.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plot the data in scatter Chart
import seaborn
seaborn.set()

plt.scatter(City_Weather_Data.Lat, City_Weather_Data.Humidity)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (03/14/2019)")

# Save png images for the scatter plot.
plt.savefig("CityLat_vs_Humidity_03.14.19.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plot the data in scatter Chart
import seaborn
seaborn.set()

plt.scatter(City_Weather_Data.Lat, City_Weather_Data.Cloudiness)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (03/14/2019)")

# Save png images for the scatter plot.
plt.savefig("CityLat_vs_Cloudiness_03.14.19.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plot the data in scatter Chart
import seaborn
seaborn.set()

plt.scatter(City_Weather_Data.Lat, City_Weather_Data.Wind_Speed)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind_Speed (03/14/2019)")

# Save png images for the scatter plot.
plt.savefig("CityLat_vs_WindSpeed_03.14.19.png")
plt.show()
